# %% [markdown]
# setting seed, loading the dataset, and visualization

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import os 
import random
import torch 
import pandas as pd

def set_all_seeds(seed: int = 42):
    """
    Reinitializes seeds for Python, NumPy, and PyTorch to ensure reproducibility.
    """
    # 1. Python's built-in random module
    random.seed(seed)
    
    # 2. NumPy
    np.random.seed(seed)
    
    # 3. PyTorch (CPU)
    torch.manual_seed(seed)
# Usage:
set_all_seeds(42) 

script_directory = os.path.dirname(os.path.abspath(__file__)) if "__file__" in globals() else os.getcwd()
dataset_path = os.path.join(script_directory, "logged_data_csv") 
line_dataset_filename = "linesrandom_52traj_20hz.csv"  
def load_data(file_path: str): 
    """
    Reads a csv and returns a numpy array of all the data 
    SETS THE INDEX TO THE TIME
    """
    df = pd.read_csv(file_path) 
    df.set_index('time',inplace=True)  
    df.drop(columns=["cs19_pos_z"], inplace=True) # removing the z axis
    df.drop(columns=["tip_pos_z"], inplace=True) 
    data = df.to_numpy() 
    return data 
lines_dataset = load_data(os.path.join(dataset_path, line_dataset_filename))  
print("length of the lines dataset: ", len(lines_dataset)) 
print("shape of the lines dataset: ", lines_dataset.shape) 

# following indices refers to the lines dataset
input_start_index = 0  
input_stop_index = 3 
state_start_index = 3 
state_stop_index = 7 

U = lines_dataset[:,input_start_index:input_stop_index] 
X= lines_dataset[:,state_start_index:state_stop_index]  
print("input and state dataset shape: ", U.shape, X.shape) 

# following indices refer to the U and X datasets
mid_x_index = 0 
mid_y_index = 1  
#mid_z_index = 2 
ee_x_index = 2 
ee_y_index = 3 
#ee_z_index = 5  
U1_index = 0 
U2_index = 1 
U3_index = 2

plt.figure() 
for i in range(U.shape[1]) : 
    plt.plot(U[:,i], label=f"U_{i+1}_t")  
    plt.legend()  
    plt.title(f"Actuator {i+1} Inputs") 
    plt.xlabel("Samples") 
    plt.ylabel(f"Actuator {i+1} Input")
    plt.show()
    plt.close()

for i in range(X.shape[1]) : 
    plt.figure() 
    plt.plot(X[:,i], label=f"X_{i+1}_t") 
    plt.legend()   
    plt.title(f"State: {i+1}") 
    plt.xlabel("Samples") 
    plt.ylabel("Displacement [m]")
    plt.show()
    plt.close()

plt.figure() 
plt.scatter(X[:,ee_x_index], X[:,ee_y_index]) 
plt.title("End Effector X and Y trajectory") 
plt.xlabel("X Axis Displacement [m]") 
plt.ylabel("Y Axis Displacement [m]") 
plt.show() 
plt.close()
# Out:
# length of the lines dataset:  7279
# shape of the lines dataset:  (7279, 7)
# input and state dataset shape:  (7279, 3) (7279, 4)

# %% [markdown]
# train, validation and testing split

# %%
def train_valid_test_split(dataset: np.array, train_percent: int, valid_percent: int) : 
    len_data = len(dataset) 
    train_size = int(train_percent*len_data) 
    valid_size = int(valid_percent*len_data) 
    train_data = dataset[0:train_size] 
    valid_data = dataset[train_size:train_size+valid_size] 
    test_data = dataset[train_size+valid_size:] 
    return train_data, valid_data, test_data 

train_percent = 0.7 
valid_percent = 0.15 
test_percent = 0.15 

train_data, valid_data, test_data = train_valid_test_split(dataset=lines_dataset, train_percent=train_percent, valid_percent=valid_percent)  

print("training data shape: ", train_data.shape) 
print("validation data shape: ", valid_data.shape) 
print("testing data shape: ", test_data.shape) 

U_train = train_data[:,input_start_index:input_stop_index] 
X_train = train_data[:, state_start_index: state_stop_index] 
print("U and X train shape: ", U_train.shape, X_train.shape)

U_valid = valid_data[:,input_start_index:input_stop_index] 
X_valid = valid_data[:, state_start_index: state_stop_index] 
print("U and X valid shape: ", U_valid.shape, X_valid.shape)

U_test = test_data[:,input_start_index:input_stop_index] 
X_test = test_data[:, state_start_index: state_stop_index] 
print("U and X test shape: ", U_test.shape, X_test.shape)
# Out:
# training data shape:  (5095, 7)
# validation data shape:  (1091, 7)
# testing data shape:  (1093, 7)
# U and X train shape:  (5095, 3) (5095, 4)
# U and X valid shape:  (1091, 3) (1091, 4)
# U and X test shape:  (1093, 3) (1093, 4)

# %% [markdown]
# scaling the dataset

# %%
from sklearn.preprocessing import MinMaxScaler 
data_scaler = MinMaxScaler(feature_range=(0,1)) 
input_scaler = MinMaxScaler(feature_range=(0,1)) 
state_scaler = MinMaxScaler(feature_range=(0,1))
ee_scaler = MinMaxScaler(feature_range=(0,1)) 
data_scaler.fit(train_data) 
input_scaler.fit(train_data[:,input_start_index:input_stop_index])   
state_scaler.fit(train_data[:,state_start_index:state_stop_index])
ee_scaler.fit(train_data[:,state_start_index+ee_x_index:state_stop_index])

train_data_transformed = data_scaler.transform(train_data) 
valid_data_transformed = data_scaler.transform(valid_data) 
test_data_transformed = data_scaler.transform(test_data) 


U_train_transformed = train_data_transformed[:,input_start_index:input_stop_index] 
X_train_transformed = train_data_transformed[:, state_start_index: state_stop_index] 
print("U and X train transformed shape: ", U_train_transformed.shape, X_train_transformed.shape)

U_valid_transformed = valid_data_transformed[:,input_start_index:input_stop_index] 
X_valid_transformed = valid_data_transformed[:, state_start_index: state_stop_index] 
print("U and X valid transformed shape: ", U_valid_transformed.shape, X_valid_transformed.shape)

U_test_transformed = test_data_transformed[:,input_start_index:input_stop_index] 
X_test_transformed = test_data_transformed[:, state_start_index: state_stop_index] 
print("U and X test transformed shape: ", U_test_transformed.shape, X_test_transformed.shape) 


future_feature = X_test_transformed[2:4,:]
future_feature.flatten('C').shape
# Out:
# U and X train transformed shape:  (5095, 3) (5095, 4)
# U and X valid transformed shape:  (1091, 3) (1091, 4)
# U and X test transformed shape:  (1093, 3) (1093, 4)
# (8,)

# %% [markdown]
# preparing dataset, creating features and labels

# %%
def prepare_dataset(U: np.array, X: np.array, lag_input: int, lag_state: int, ee_x_index: int, ee_y_index: int) : 
    
    features = [] 
    labels = [] 

    max_lag = max(lag_input, lag_state)

    for i in range(max_lag, len(U)-1) : 
        future_feature = X[i+1,ee_x_index:ee_y_index+1] 
        current_feature = X[i,:] 
        if lag_state == 0 : 
            past_feature = X[i:i] 
        else : 
            past_feature = X[i-lag_state:i,:] 
            past_feature = past_feature.flatten('C')
        current_input = U[i,:] 
        if lag_input == 0 : 
            past_input = U[i:i]  
        else : 
            past_input = U[i-lag_input:i,:] 
            past_input = past_input.flatten('C') 
        
        if past_feature.size == 0 and past_input.size == 0 : 
            joined_features = np.concatenate((future_feature, current_feature, current_input), axis=0) 
        elif past_feature.size != 0 and past_input.size == 0 : 
            joined_features = np.concatenate((future_feature, current_feature, past_feature, current_input), axis=0)
        elif past_feature.size == 0 and past_input.size != 0 : 
            joined_features = np.concatenate((future_feature, current_feature, current_input, past_input), axis=0) 
        else : 
            joined_features = np.concatenate((future_feature, current_feature, past_feature, current_input, past_input), axis=0) 

        features.append(joined_features) 

        labels.append(U[i+1]) 
    
    features = np.array(features) 
    labels = np.array(labels)  

    return features, labels

# %%
lag_input = 0 
lag_state = 3 

train_features, train_labels = prepare_dataset(U=U_train_transformed, X=X_train_transformed, lag_input=lag_input, lag_state=lag_state,
                                               ee_x_index=ee_x_index, ee_y_index=ee_y_index) 
print("shape of the training features and labels: ", train_features.shape, train_labels.shape) 

valid_features, valid_labels = prepare_dataset(U=U_valid_transformed, X=X_valid_transformed, lag_input=lag_input, lag_state=lag_state,
                                               ee_x_index=ee_x_index, ee_y_index=ee_y_index) 
print("shape of the validation features and labels: ", valid_features.shape, valid_labels.shape) 

test_features, test_labels = prepare_dataset(U=U_test_transformed, X=X_test_transformed, lag_input=lag_input, lag_state=lag_state,
                                             ee_x_index=ee_x_index, ee_y_index=ee_y_index) 
print("shape of the testing features and labels: ", test_features.shape, test_labels.shape)
# Out:
# shape of the training features and labels:  (5091, 21) (5091, 3)
# shape of the validation features and labels:  (1087, 21) (1087, 3)
# shape of the testing features and labels:  (1089, 21) (1089, 3)

# %% [markdown]
# conversion to tensor (torch.float32) and creation of dataloaders

# %%
import torch 

train_features_tensor = torch.from_numpy(train_features).type(dtype=torch.float32) 
train_labels_tensor = torch.from_numpy(train_labels).type(dtype=torch.float32) 
valid_features_tensor = torch.from_numpy(valid_features).type(dtype=torch.float32) 
valid_labels_tensor = torch.from_numpy(valid_labels).type(dtype=torch.float32) 
test_features_tensor = torch.from_numpy(test_features).type(dtype=torch.float32) 
test_labels_tensor = torch.from_numpy(test_labels).type(dtype=torch.float32) 

print("training feature and label tensor shape and datatype: ", train_features_tensor.shape, train_labels_tensor.shape, train_labels_tensor.dtype)
print("validation feature and label tensor shape and datatype: ", valid_features_tensor.shape, valid_labels_tensor.shape, valid_labels_tensor.dtype)
print("testing feature and label tensor shape and datatype: ", test_features_tensor.shape, test_labels_tensor.shape, test_labels_tensor.dtype) 

from torch.utils.data import TensorDataset, DataLoader 
train_dataset = TensorDataset(train_features_tensor, train_labels_tensor) 
valid_dataset = TensorDataset(valid_features_tensor, valid_labels_tensor)
test_dataset = TensorDataset(test_features_tensor, test_labels_tensor) 

batch_size = 16

train_dataloader = DataLoader(train_dataset, batch_size=batch_size) 
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size) 
test_dataloader = DataLoader(test_dataset, batch_size=batch_size) 

print("train dataloader length: ", len(train_dataloader)) 
print("valid dataloader length: ", len(valid_dataloader)) 
print("test dataloader length: ", len(test_dataloader)) 

for X,Y in train_dataloader : 
    print("shape of a single batch feature and label: ", X.shape, Y.shape)  
    break
# Out:
# training feature and label tensor shape and datatype:  torch.Size([5091, 21]) torch.Size([5091, 3]) torch.float32
# validation feature and label tensor shape and datatype:  torch.Size([1087, 21]) torch.Size([1087, 3]) torch.float32
# testing feature and label tensor shape and datatype:  torch.Size([1089, 21]) torch.Size([1089, 3]) torch.float32
# train dataloader length:  319
# valid dataloader length:  68
# test dataloader length:  69
# shape of a single batch feature and label:  torch.Size([16, 21]) torch.Size([16, 3])

# %% [markdown]
# defining and creating the network

# %%
class MLP_model(torch.nn.Module): 
    def __init__(self, input_flat_size:int, hidden_units:int, output_size:int, num_hidden_layers:int) :
        super().__init__()
        self.input_flat_size = input_flat_size 
        self.hidden_units = hidden_units 
        self.output_size = output_size 
        self.num_hidden_layers = num_hidden_layers 

        layers = [] 

        in_dimension = self.input_flat_size 

        self.input_layer = torch.nn.Linear(in_features=in_dimension, out_features=self.hidden_units) 
        
        for i in range(self.num_hidden_layers) : 
            layers.append(torch.nn.Linear(in_features=self.hidden_units, out_features=self.hidden_units)) 
            layers.append(torch.nn.ReLU()) 

        self.backbone = torch.nn.Sequential(*layers) 
        
        self.output_layer = torch.nn.Linear(in_features=self.hidden_units, out_features=self.output_size) 

        #self.tanh = torch.nn.Tanh() 
        self.relu = torch.nn.ReLU()
        #self.leakyrelu = torch.nn.LeakyReLU()    

    def forward(self,x): 
        out = self.input_layer(x) 
        out = self.relu(out)
        #out = self.backbone(out)  
        out = self.output_layer(out) 
        return out

# %%
input_flat_size = train_features.shape[1]
output_size = train_labels.shape[1] 

num_hidden_layers = 1
hidden_units = 30 

inverse_model = MLP_model(input_flat_size=input_flat_size, hidden_units=hidden_units, output_size=output_size, num_hidden_layers=num_hidden_layers) 

from torchinfo import summary 
print(summary(model=inverse_model, input_size=(1,input_flat_size)))

loss_fn = torch.nn.MSELoss() 
learning_rate_teacherforcing = 0.0001   
learning_rate_autoregressive = 0.0001 

optimizer_teacherforcing = torch.optim.Adam(inverse_model.parameters(), lr=learning_rate_teacherforcing) 
optimizer_autoregressive = torch.optim.Adam(inverse_model.parameters(), lr=learning_rate_autoregressive)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MLP_model                                [1, 3]                    930
# ├─Linear: 1-1                            [1, 30]                   660
# ├─ReLU: 1-2                              [1, 30]                   --
# ├─Linear: 1-3                            [1, 3]                    93
# ==========================================================================================
# Total params: 1,683
# Trainable params: 1,683
# Non-trainable params: 0
# Total mult-adds (M): 0.00
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ==========================================================================================

# %% [markdown]
# teacher forcing training function

# %%
def train_teacherforcing(model: torch.nn.Module, train_dataloader: DataLoader, valid_dataloader: DataLoader, 
                         optimizer: torch.optim.Optimizer, loss_fn: torch.nn.Module,
                         epochs: int, model_name: str, early_stopping_call = None) : 
    
    results = {"train_loss": [], "valid_loss": []} 

    for epoch in range(epochs) : 
        
        model.train() 

        total_loss_per_epoch = 0.0 

        for batch_num, (X,Y) in enumerate(train_dataloader) : 

            y_pred = model(X) 

            loss = loss_fn(y_pred, Y) 

            total_loss_per_epoch += loss.item() 

            optimizer.zero_grad() 

            loss.backward() 

            optimizer.step() 

        average_train_loss_per_epoch = total_loss_per_epoch/len(train_dataloader) 

        results["train_loss"].append(average_train_loss_per_epoch) 

        model.eval() 

        total_validation_loss_per_epoch = 0.0 

        with torch.inference_mode() : 
            
            for batch, (X_valid,Y_valid) in enumerate(valid_dataloader) : 

                y_pred_valid = model(X_valid) 

                loss = loss_fn(y_pred_valid, Y_valid) 

                total_validation_loss_per_epoch += loss.item() 
        
        average_valid_loss_per_epoch = total_validation_loss_per_epoch/len(valid_dataloader)
        
        results["valid_loss"].append(average_valid_loss_per_epoch) 

        print(
            f"{model_name} | "
            f"Epoch: {epoch + 1} | "
            f"Train Loss: {average_train_loss_per_epoch:.6f} | " # :.4f keep 4 decimal places 
            f"Validation_Loss: {average_valid_loss_per_epoch:.6f} | " 
        ) 

        if early_stopping_call is not None: 
            early_stopping_call(average_valid_loss_per_epoch)
            if early_stopping_call.early_stop : 
                print("Early Stopping Triggered") 
                break

    return results

# %% [markdown]
# autoregressive training function

# %%
def train_autoregressive(model: torch.nn.Module, U_scaled_train: np.array, X_scaled_train: np.array, 
                         U_scaled_valid: np.array, X_scaled_valid: np.array, 
                         lag_input: int, lag_state: int, ee_x_index: int, ee_y_index: int, 
                         epochs: int, optimizer: torch.optim.Optimizer, loss_fn: torch.nn.Module, 
                         model_name: str, chunk_length: int, early_stopping_call = None):   
    
    results = {"train_loss": [], "valid_loss": []}

    U_train = torch.from_numpy(U_scaled_train).type(torch.float32)
    X_train = torch.from_numpy(X_scaled_train).type(torch.float32)
    U_valid = torch.from_numpy(U_scaled_valid).type(torch.float32)
    X_valid = torch.from_numpy(X_scaled_valid).type(torch.float32)  

    max_lag = max(lag_input, lag_state)

    for epoch in range(epochs): 

        U_train_buffer = U_train.clone()
        U_valid_buffer = U_valid.clone()

        model.train() 
        optimizer.zero_grad() 

        preds = []  
        labels = [] 

        total_loss = 0 
        step = 0  
        counter = 0

        # initial buffer filled with ground truth 
        future_state = X_train[max_lag+1,ee_x_index:ee_y_index+1] 
        current_state = X_train[max_lag,:] 
        if lag_state == 0 : 
            past_state = X_train[max_lag:max_lag] 
        else : 
            past_state = X_train[max_lag-lag_state:max_lag,:] 
            past_state = torch.flatten(input=past_state) 
        current_input = U_train[max_lag,:] 
        if lag_input == 0 : 
            past_input = U_train[max_lag:max_lag,:]
        else : 
            past_input = U_train[max_lag-lag_input:max_lag,:] 
            past_input = torch.flatten(input=past_input) 

        if past_state.size(dim=0) == 0 and past_input.size(dim=0) == 0 : 
            joined_features = torch.concatenate((future_state, current_state, current_input), dim=0) 
        elif past_state.size(dim=0) != 0 and past_input.size(dim=0) == 0 : 
            joined_features = torch.concatenate((future_state, current_state, past_state, current_input), dim=0)
        elif past_state.size(dim=0) == 0 and past_input.size(dim=0) != 0 : 
            joined_features = torch.concatenate((future_state, current_state, current_input, past_input), dim=0) 
        else : 
            joined_features = torch.concatenate((future_state, current_state, past_state, current_input, past_input), dim=0)  

        for i in range(max_lag+1, len(U_train)) : 

            pred = model(joined_features.unsqueeze(0)) 
            pred = pred.squeeze(0) 

            step += 1 

            preds.append(pred)  

            labels.append(U_train[i])

            U_train_buffer[i,:] = pred  

            if i < len(U_train) - 1 :

                # buffer update 
                future_state = X_train[i+1,ee_x_index:ee_y_index+1]
                current_state = X_train[i,:]
                if lag_state == 0 : 
                    past_state = X_train[i:i] 
                else : 
                    past_state = X_train[i-lag_state:i,:] 
                    past_state = torch.flatten(input=past_state)
                current_input = pred 
                if lag_input == 0 : 
                    past_input = U_train[i:i,:]
                else : 
                    past_input = U_train_buffer[i-lag_input:i,:] 
                    past_input = torch.flatten(input=past_input) 

                if past_state.size(dim=0) == 0 and past_input.size(dim=0) == 0 : 
                    joined_features = torch.concatenate((future_state, current_state, current_input), dim=0) 
                elif past_state.size(dim=0) != 0 and past_input.size(dim=0) == 0 : 
                    joined_features = torch.concatenate((future_state, current_state, past_state, current_input), dim=0)
                elif past_state.size(dim=0) == 0 and past_input.size(dim=0) != 0 : 
                    joined_features = torch.concatenate((future_state, current_state, current_input, past_input), dim=0) 
                else : 
                    joined_features = torch.concatenate((future_state, current_state, past_state, current_input, past_input), dim=0) 

            else : 
                pass  

            if step == chunk_length or i == len(U_train) - 1:  

                preds_tensor = torch.stack(preds, dim=0)  

                labels_tensor = torch.stack(labels, dim=0)

                loss = loss_fn(preds_tensor, labels_tensor)  

                loss.backward() 
                total_loss += loss.item()
                optimizer.step()  
                optimizer.zero_grad()


                current_input = current_input.detach() 
                U_train_buffer = U_train_buffer.detach() 
                joined_features = joined_features.detach()

                total_loss += loss.item() 
                
                step = 0 
                preds = [] 
                labels = []   
                counter += 1  
            else : 
                pass

        train_loss = total_loss/counter

        # validation 
        model.eval() 

        preds = []

        # initial buffer filled with ground truth 
        future_state = X_valid[max_lag+1,ee_x_index:ee_y_index+1] 
        current_state = X_valid[max_lag,:] 
        if lag_state == 0 : 
            past_state = X_valid[max_lag:max_lag] 
        else : 
            past_state = X_valid[max_lag-lag_state:max_lag,:] 
            past_state = torch.flatten(input=past_state) 
        current_input = U_valid[max_lag,:] 
        if lag_input == 0 : 
            past_input = U_valid[max_lag:max_lag,:]
        else : 
            past_input = U_valid[max_lag-lag_input:max_lag,:] 
            past_input = torch.flatten(input=past_input) 

        if past_state.size(dim=0) == 0 and past_input.size(dim=0) == 0 : 
            joined_features = torch.concatenate((future_state, current_state, current_input), dim=0) 
        elif past_state.size(dim=0) != 0 and past_input.size(dim=0) == 0 : 
            joined_features = torch.concatenate((future_state, current_state, past_state, current_input), dim=0)
        elif past_state.size(dim=0) == 0 and past_input.size(dim=0) != 0 : 
            joined_features = torch.concatenate((future_state, current_state, current_input, past_input), dim=0) 
        else : 
            joined_features = torch.concatenate((future_state, current_state, past_state, current_input, past_input), dim=0) 
        
        with torch.inference_mode() :  

            for i in range(max_lag+1, len(U_valid)) : 

                pred = model(joined_features.unsqueeze(0)) 
                pred = pred.squeeze(0) 

                preds.append(pred) 

                U_valid_buffer[i,:] = pred  

                if i < len(U_valid) - 1 : 

                    # buffer update 
                    future_state = X_valid[i+1,ee_x_index:ee_y_index+1]
                    current_state = X_valid[i,:]
                    if lag_state == 0 : 
                        past_state = X_valid[i:i] 
                    else : 
                        past_state = X_valid[i-lag_state:i,:] 
                        past_state = torch.flatten(input=past_state)
                    current_input = pred 
                    if lag_input == 0 : 
                        past_input = U_valid[i:i,:]
                    else : 
                        past_input = U_valid_buffer[i-lag_input:i,:] 
                        past_input = torch.flatten(input=past_input)  

                    if past_state.size(dim=0) == 0 and past_input.size(dim=0) == 0 : 
                        joined_features = torch.concatenate((future_state, current_state, current_input), dim=0) 
                    elif past_state.size(dim=0) != 0 and past_input.size(dim=0) == 0 : 
                        joined_features = torch.concatenate((future_state, current_state, past_state, current_input), dim=0)
                    elif past_state.size(dim=0) == 0 and past_input.size(dim=0) != 0 : 
                        joined_features = torch.concatenate((future_state, current_state, current_input, past_input), dim=0) 
                    else : 
                        joined_features = torch.concatenate((future_state, current_state, past_state, current_input, past_input), dim=0)
                     

                else : 
                    pass

        preds_tensor = torch.stack(preds, dim=0) 

        targets = U_valid[max_lag+1:] 

        loss = loss_fn(preds_tensor, targets) 

        valid_loss = loss.item() 

        print(
        f"Model: {model_name} |"
        f"Epoch: {epoch + 1} | "
        f"Train Loss: {train_loss:.6f} | " 
        f"Validation_Loss: {valid_loss:.6f} | " 
        ) 

        results["train_loss"].append(train_loss) 
        results["valid_loss"].append(valid_loss)

        if early_stopping_call is not None: 
            early_stopping_call(valid_loss) 
            if early_stopping_call.early_stop : 
                print("Early Stopping Triggered") 
                break 

    return results

# %% [markdown]
# defining early stopping function

# %%
class EarlyStopping:
    def __init__(self, patience=6, min_delta=0.0):
        """
        patience: number of epochs to wait for improvement
        min_delta: minimum improvement in validation loss to count as progress
        """
        self.patience = patience
        self.min_delta = min_delta
        self.best_loss = np.inf
        self.counter = 0
        self.early_stop = False

    def __call__(self, val_loss):
        if val_loss < self.best_loss - self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

# %% [markdown]
# initializing the training

# %%
epochs_teacherforcing = 2000
epochs_autoregressive = 2000 

model_name_tf = "MLP_IK_TF" 
model_name_ar = "MLP_IK_AR" 

early_stoppper_tf = EarlyStopping(patience=6, min_delta=0)
early_stoppper_ar = EarlyStopping(patience=6, min_delta=0) 

chunk_length = 10 

'''
train_results_tf = train_teacherforcing(model=inverse_model, train_dataloader=train_dataloader, valid_dataloader=valid_dataloader, optimizer=optimizer_teacherforcing, 
                                        loss_fn=loss_fn, epochs=epochs_teacherforcing, model_name=model_name_tf, early_stopping_call=early_stoppper_tf)
                                        '''


train_results_ar = train_autoregressive(model=inverse_model, U_scaled_train=U_train_transformed, X_scaled_train=X_train_transformed,
                                        U_scaled_valid=U_valid_transformed, X_scaled_valid=X_valid_transformed, lag_input=lag_input, lag_state=lag_state,
                                        ee_x_index=ee_x_index, ee_y_index=ee_y_index, 
                                        epochs=epochs_autoregressive, optimizer=optimizer_autoregressive, loss_fn=loss_fn, model_name=model_name_ar, chunk_length=chunk_length , early_stopping_call=early_stoppper_ar)
# Out:
# Model: MLP_IK_AR |Epoch: 1 | Train Loss: 0.197870 | Validation_Loss: 0.078619 |
# Model: MLP_IK_AR |Epoch: 2 | Train Loss: 0.166076 | Validation_Loss: 0.070813 |
# Model: MLP_IK_AR |Epoch: 3 | Train Loss: 0.152841 | Validation_Loss: 0.064186 |
# Model: MLP_IK_AR |Epoch: 4 | Train Loss: 0.140226 | Validation_Loss: 0.056051 |
# Model: MLP_IK_AR |Epoch: 5 | Train Loss: 0.127391 | Validation_Loss: 0.050156 |
# Model: MLP_IK_AR |Epoch: 6 | Train Loss: 0.117917 | Validation_Loss: 0.045280 |
# Model: MLP_IK_AR |Epoch: 7 | Train Loss: 0.109602 | Validation_Loss: 0.040910 |
# Model: MLP_IK_AR |Epoch: 8 | Train Loss: 0.102632 | Validation_Loss: 0.037597 |
# Model: MLP_IK_AR |Epoch: 9 | Train Loss: 0.096921 | Validation_Loss: 0.034803 |
# Model: MLP_IK_AR |Epoch: 10 | Train Loss: 0.091951 | Validation_Loss: 0.032390 |
# Model: MLP_IK_AR |Epoch: 11 | Train Loss: 0.087517 | Validation_Loss: 0.030315 |
# Model: MLP_IK_AR |Epoch: 12 | Train Loss: 0.083549 | Validation_Loss: 0.028438 |
# Model: MLP_IK_AR |Epoch: 13 | Train Loss: 0.079966 | Validation_Loss: 0.026653 |
# Model: MLP_IK_AR |Epoch: 14 | Train Loss: 0.076746 | Validation_Loss: 0.025080 |
# Model: MLP_IK_AR |Epoch: 15 | Train Loss: 0.073877 | Validation_Loss: 0.023731 |
# Model: MLP_IK_AR |Epoch: 16 | Train Loss: 0.071507 | Validation_Loss: 0.022675 |
# Model: MLP_IK_AR |Epoch: 17 | Train Loss: 0.069562 | Validation_Loss: 0.021763 |
# Model: MLP_IK_AR |Epoch: 18 | Train Loss: 0.067885 | Validation_Loss: 0.020982 |
# Model: MLP_IK_AR |Epoch: 19 | Train Loss: 0.066446 | Validation_Loss: 0.020273 |
# Model: MLP_IK_AR |Epoch: 20 | Train Loss: 0.065199 | Validation_Loss: 0.019736 |
# Model: MLP_IK_AR |Epoch: 21 | Train Loss: 0.064176 | Validation_Loss: 0.019284 |
# Model: MLP_IK_AR |Epoch: 22 | Train Loss: 0.063060 | Validation_Loss: 0.018659 |
# Model: MLP_IK_AR |Epoch: 23 | Train Loss: 0.061540 | Validation_Loss: 0.018245 |
# Model: MLP_IK_AR |Epoch: 24 | Train Loss: 0.060605 | Validation_Loss: 0.017861 |
# Model: MLP_IK_AR |Epoch: 25 | Train Loss: 0.059525 | Validation_Loss: 0.017541 |
# Model: MLP_IK_AR |Epoch: 26 | Train Loss: 0.058458 | Validation_Loss: 0.017268 |
# Model: MLP_IK_AR |Epoch: 27 | Train Loss: 0.057607 | Validation_Loss: 0.017024 |
# Model: MLP_IK_AR |Epoch: 28 | Train Loss: 0.056839 | Validation_Loss: 0.016787 |
# Model: MLP_IK_AR |Epoch: 29 | Train Loss: 0.056103 | Validation_Loss: 0.016557 |
# Model: MLP_IK_AR |Epoch: 30 | Train Loss: 0.055381 | Validation_Loss: 0.016328 |
# Model: MLP_IK_AR |Epoch: 31 | Train Loss: 0.054686 | Validation_Loss: 0.016096 |
# Model: MLP_IK_AR |Epoch: 32 | Train Loss: 0.053952 | Validation_Loss: 0.015936 |
# Model: MLP_IK_AR |Epoch: 33 | Train Loss: 0.053207 | Validation_Loss: 0.015677 |
# Model: MLP_IK_AR |Epoch: 34 | Train Loss: 0.052415 | Validation_Loss: 0.015489 |
# Model: MLP_IK_AR |Epoch: 35 | Train Loss: 0.051676 | Validation_Loss: 0.015197 |
# Model: MLP_IK_AR |Epoch: 36 | Train Loss: 0.050928 | Validation_Loss: 0.014988 |
# Model: MLP_IK_AR |Epoch: 37 | Train Loss: 0.050231 | Validation_Loss: 0.014712 |
# Model: MLP_IK_AR |Epoch: 38 | Train Loss: 0.049568 | Validation_Loss: 0.014486 |
# Model: MLP_IK_AR |Epoch: 39 | Train Loss: 0.048904 | Validation_Loss: 0.014230 |
# Model: MLP_IK_AR |Epoch: 40 | Train Loss: 0.048346 | Validation_Loss: 0.013979 |
# Model: MLP_IK_AR |Epoch: 41 | Train Loss: 0.047706 | Validation_Loss: 0.013786 |
# Model: MLP_IK_AR |Epoch: 42 | Train Loss: 0.047185 | Validation_Loss: 0.013509 |
# Model: MLP_IK_AR |Epoch: 43 | Train Loss: 0.046697 | Validation_Loss: 0.013270 |
# Model: MLP_IK_AR |Epoch: 44 | Train Loss: 0.046153 | Validation_Loss: 0.013014 |
# Model: MLP_IK_AR |Epoch: 45 | Train Loss: 0.045751 | Validation_Loss: 0.012879 |
# Model: MLP_IK_AR |Epoch: 46 | Train Loss: 0.045298 | Validation_Loss: 0.012652 |
# Model: MLP_IK_AR |Epoch: 47 | Train Loss: 0.044902 | Validation_Loss: 0.012512 |
# Model: MLP_IK_AR |Epoch: 48 | Train Loss: 0.044514 | Validation_Loss: 0.012262 |
# Model: MLP_IK_AR |Epoch: 49 | Train Loss: 0.044155 | Validation_Loss: 0.012099 |
# Model: MLP_IK_AR |Epoch: 50 | Train Loss: 0.043816 | Validation_Loss: 0.011869 |
# Model: MLP_IK_AR |Epoch: 51 | Train Loss: 0.043532 | Validation_Loss: 0.011719 |
# Model: MLP_IK_AR |Epoch: 52 | Train Loss: 0.043250 | Validation_Loss: 0.011519 |
# Model: MLP_IK_AR |Epoch: 53 | Train Loss: 0.042946 | Validation_Loss: 0.011374 |
# Model: MLP_IK_AR |Epoch: 54 | Train Loss: 0.042708 | Validation_Loss: 0.011191 |
# Model: MLP_IK_AR |Epoch: 55 | Train Loss: 0.042439 | Validation_Loss: 0.011087 |
# Model: MLP_IK_AR |Epoch: 56 | Train Loss: 0.042206 | Validation_Loss: 0.010925 |
# Model: MLP_IK_AR |Epoch: 57 | Train Loss: 0.041965 | Validation_Loss: 0.010835 |
# Model: MLP_IK_AR |Epoch: 58 | Train Loss: 0.041753 | Validation_Loss: 0.010688 |
# Model: MLP_IK_AR |Epoch: 59 | Train Loss: 0.041530 | Validation_Loss: 0.010615 |
# Model: MLP_IK_AR |Epoch: 60 | Train Loss: 0.041333 | Validation_Loss: 0.010494 |
# Model: MLP_IK_AR |Epoch: 61 | Train Loss: 0.041148 | Validation_Loss: 0.010429 |
# Model: MLP_IK_AR |Epoch: 62 | Train Loss: 0.040980 | Validation_Loss: 0.010309 |
# Model: MLP_IK_AR |Epoch: 63 | Train Loss: 0.040798 | Validation_Loss: 0.010261 |
# Model: MLP_IK_AR |Epoch: 64 | Train Loss: 0.040638 | Validation_Loss: 0.010165 |
# Model: MLP_IK_AR |Epoch: 65 | Train Loss: 0.040486 | Validation_Loss: 0.010121 |
# Model: MLP_IK_AR |Epoch: 66 | Train Loss: 0.040352 | Validation_Loss: 0.010043 |
# Model: MLP_IK_AR |Epoch: 67 | Train Loss: 0.040212 | Validation_Loss: 0.010004 |
# Model: MLP_IK_AR |Epoch: 68 | Train Loss: 0.040084 | Validation_Loss: 0.009929 |
# Model: MLP_IK_AR |Epoch: 69 | Train Loss: 0.039955 | Validation_Loss: 0.009898 |
# Model: MLP_IK_AR |Epoch: 70 | Train Loss: 0.039846 | Validation_Loss: 0.009860 |
# Model: MLP_IK_AR |Epoch: 71 | Train Loss: 0.039736 | Validation_Loss: 0.009786 |
# Model: MLP_IK_AR |Epoch: 72 | Train Loss: 0.039625 | Validation_Loss: 0.009756 |
# Model: MLP_IK_AR |Epoch: 73 | Train Loss: 0.039538 | Validation_Loss: 0.009713 |
# Model: MLP_IK_AR |Epoch: 74 | Train Loss: 0.039465 | Validation_Loss: 0.009652 |
# Model: MLP_IK_AR |Epoch: 75 | Train Loss: 0.039373 | Validation_Loss: 0.009622 |
# Model: MLP_IK_AR |Epoch: 76 | Train Loss: 0.039297 | Validation_Loss: 0.009570 |
# Model: MLP_IK_AR |Epoch: 77 | Train Loss: 0.039210 | Validation_Loss: 0.009546 |
# Model: MLP_IK_AR |Epoch: 78 | Train Loss: 0.039138 | Validation_Loss: 0.009501 |
# Model: MLP_IK_AR |Epoch: 79 | Train Loss: 0.039081 | Validation_Loss: 0.009469 |
# Model: MLP_IK_AR |Epoch: 80 | Train Loss: 0.039013 | Validation_Loss: 0.009439 |
# Model: MLP_IK_AR |Epoch: 81 | Train Loss: 0.038945 | Validation_Loss: 0.009409 |
# Model: MLP_IK_AR |Epoch: 82 | Train Loss: 0.038878 | Validation_Loss: 0.009386 |
# Model: MLP_IK_AR |Epoch: 83 | Train Loss: 0.038828 | Validation_Loss: 0.009363 |
# Model: MLP_IK_AR |Epoch: 84 | Train Loss: 0.038769 | Validation_Loss: 0.009338 |
# Model: MLP_IK_AR |Epoch: 85 | Train Loss: 0.038717 | Validation_Loss: 0.009318 |
# Model: MLP_IK_AR |Epoch: 86 | Train Loss: 0.038663 | Validation_Loss: 0.009297 |
# Model: MLP_IK_AR |Epoch: 87 | Train Loss: 0.038619 | Validation_Loss: 0.009276 |
# Model: MLP_IK_AR |Epoch: 88 | Train Loss: 0.038580 | Validation_Loss: 0.009257 |
# Model: MLP_IK_AR |Epoch: 89 | Train Loss: 0.038516 | Validation_Loss: 0.009233 |
# Model: MLP_IK_AR |Epoch: 90 | Train Loss: 0.038471 | Validation_Loss: 0.009219 |
# Model: MLP_IK_AR |Epoch: 91 | Train Loss: 0.038417 | Validation_Loss: 0.009202 |
# Model: MLP_IK_AR |Epoch: 92 | Train Loss: 0.038397 | Validation_Loss: 0.009183 |
# Model: MLP_IK_AR |Epoch: 93 | Train Loss: 0.038306 | Validation_Loss: 0.009171 |
# Model: MLP_IK_AR |Epoch: 94 | Train Loss: 0.038299 | Validation_Loss: 0.009150 |
# Model: MLP_IK_AR |Epoch: 95 | Train Loss: 0.038219 | Validation_Loss: 0.009140 |
# Model: MLP_IK_AR |Epoch: 96 | Train Loss: 0.038194 | Validation_Loss: 0.009118 |
# Model: MLP_IK_AR |Epoch: 97 | Train Loss: 0.038125 | Validation_Loss: 0.009107 |
# Model: MLP_IK_AR |Epoch: 98 | Train Loss: 0.038086 | Validation_Loss: 0.009086 |
# Model: MLP_IK_AR |Epoch: 99 | Train Loss: 0.038046 | Validation_Loss: 0.009075 |
# Model: MLP_IK_AR |Epoch: 100 | Train Loss: 0.037995 | Validation_Loss: 0.009061 |
# Model: MLP_IK_AR |Epoch: 101 | Train Loss: 0.037948 | Validation_Loss: 0.009044 |
# Model: MLP_IK_AR |Epoch: 102 | Train Loss: 0.037901 | Validation_Loss: 0.009031 |
# Model: MLP_IK_AR |Epoch: 103 | Train Loss: 0.037860 | Validation_Loss: 0.009016 |
# Model: MLP_IK_AR |Epoch: 104 | Train Loss: 0.037823 | Validation_Loss: 0.009001 |
# Model: MLP_IK_AR |Epoch: 105 | Train Loss: 0.037780 | Validation_Loss: 0.008986 |
# Model: MLP_IK_AR |Epoch: 106 | Train Loss: 0.037734 | Validation_Loss: 0.008973 |
# Model: MLP_IK_AR |Epoch: 107 | Train Loss: 0.037698 | Validation_Loss: 0.008962 |
# Model: MLP_IK_AR |Epoch: 108 | Train Loss: 0.037657 | Validation_Loss: 0.008949 |
# Model: MLP_IK_AR |Epoch: 109 | Train Loss: 0.037618 | Validation_Loss: 0.008928 |
# Model: MLP_IK_AR |Epoch: 110 | Train Loss: 0.037580 | Validation_Loss: 0.008916 |
# Model: MLP_IK_AR |Epoch: 111 | Train Loss: 0.037536 | Validation_Loss: 0.008902 |
# Model: MLP_IK_AR |Epoch: 112 | Train Loss: 0.037491 | Validation_Loss: 0.008889 |
# Model: MLP_IK_AR |Epoch: 113 | Train Loss: 0.037455 | Validation_Loss: 0.008877 |
# Model: MLP_IK_AR |Epoch: 114 | Train Loss: 0.037416 | Validation_Loss: 0.008866 |
# Model: MLP_IK_AR |Epoch: 115 | Train Loss: 0.037375 | Validation_Loss: 0.008857 |
# Model: MLP_IK_AR |Epoch: 116 | Train Loss: 0.037331 | Validation_Loss: 0.008846 |
# Model: MLP_IK_AR |Epoch: 117 | Train Loss: 0.037284 | Validation_Loss: 0.008835 |
# Model: MLP_IK_AR |Epoch: 118 | Train Loss: 0.037228 | Validation_Loss: 0.008821 |
# Model: MLP_IK_AR |Epoch: 119 | Train Loss: 0.037188 | Validation_Loss: 0.008810 |
# Model: MLP_IK_AR |Epoch: 120 | Train Loss: 0.037149 | Validation_Loss: 0.008798 |
# Model: MLP_IK_AR |Epoch: 121 | Train Loss: 0.037103 | Validation_Loss: 0.008785 |
# Model: MLP_IK_AR |Epoch: 122 | Train Loss: 0.037060 | Validation_Loss: 0.008768 |
# Model: MLP_IK_AR |Epoch: 123 | Train Loss: 0.037032 | Validation_Loss: 0.008757 |
# Model: MLP_IK_AR |Epoch: 124 | Train Loss: 0.036987 | Validation_Loss: 0.008742 |
# Model: MLP_IK_AR |Epoch: 125 | Train Loss: 0.036948 | Validation_Loss: 0.008728 |
# Model: MLP_IK_AR |Epoch: 126 | Train Loss: 0.036917 | Validation_Loss: 0.008718 |
# Model: MLP_IK_AR |Epoch: 127 | Train Loss: 0.036882 | Validation_Loss: 0.008707 |
# Model: MLP_IK_AR |Epoch: 128 | Train Loss: 0.036847 | Validation_Loss: 0.008697 |
# Model: MLP_IK_AR |Epoch: 129 | Train Loss: 0.036815 | Validation_Loss: 0.008687 |
# Model: MLP_IK_AR |Epoch: 130 | Train Loss: 0.036768 | Validation_Loss: 0.008674 |
# Model: MLP_IK_AR |Epoch: 131 | Train Loss: 0.036743 | Validation_Loss: 0.008662 |
# Model: MLP_IK_AR |Epoch: 132 | Train Loss: 0.036691 | Validation_Loss: 0.008648 |
# Model: MLP_IK_AR |Epoch: 133 | Train Loss: 0.036671 | Validation_Loss: 0.008637 |
# Model: MLP_IK_AR |Epoch: 134 | Train Loss: 0.036624 | Validation_Loss: 0.008623 |
# Model: MLP_IK_AR |Epoch: 135 | Train Loss: 0.036600 | Validation_Loss: 0.008610 |
# Model: MLP_IK_AR |Epoch: 136 | Train Loss: 0.036564 | Validation_Loss: 0.008596 |
# Model: MLP_IK_AR |Epoch: 137 | Train Loss: 0.036526 | Validation_Loss: 0.008583 |
# Model: MLP_IK_AR |Epoch: 138 | Train Loss: 0.036490 | Validation_Loss: 0.008568 |
# Model: MLP_IK_AR |Epoch: 139 | Train Loss: 0.036463 | Validation_Loss: 0.008553 |
# Model: MLP_IK_AR |Epoch: 140 | Train Loss: 0.036422 | Validation_Loss: 0.008538 |
# Model: MLP_IK_AR |Epoch: 141 | Train Loss: 0.036401 | Validation_Loss: 0.008527 |
# Model: MLP_IK_AR |Epoch: 142 | Train Loss: 0.036354 | Validation_Loss: 0.008510 |
# Model: MLP_IK_AR |Epoch: 143 | Train Loss: 0.036332 | Validation_Loss: 0.008496 |
# Model: MLP_IK_AR |Epoch: 144 | Train Loss: 0.036299 | Validation_Loss: 0.008483 |
# Model: MLP_IK_AR |Epoch: 145 | Train Loss: 0.036276 | Validation_Loss: 0.008473 |
# Model: MLP_IK_AR |Epoch: 146 | Train Loss: 0.036236 | Validation_Loss: 0.008461 |
# Model: MLP_IK_AR |Epoch: 147 | Train Loss: 0.036209 | Validation_Loss: 0.008446 |
# Model: MLP_IK_AR |Epoch: 148 | Train Loss: 0.036184 | Validation_Loss: 0.008432 |
# Model: MLP_IK_AR |Epoch: 149 | Train Loss: 0.036155 | Validation_Loss: 0.008421 |
# Model: MLP_IK_AR |Epoch: 150 | Train Loss: 0.036113 | Validation_Loss: 0.008407 |
# Model: MLP_IK_AR |Epoch: 151 | Train Loss: 0.036086 | Validation_Loss: 0.008395 |
# Model: MLP_IK_AR |Epoch: 152 | Train Loss: 0.036064 | Validation_Loss: 0.008383 |
# Model: MLP_IK_AR |Epoch: 153 | Train Loss: 0.036026 | Validation_Loss: 0.008369 |
# Model: MLP_IK_AR |Epoch: 154 | Train Loss: 0.035999 | Validation_Loss: 0.008355 |
# Model: MLP_IK_AR |Epoch: 155 | Train Loss: 0.035970 | Validation_Loss: 0.008342 |
# Model: MLP_IK_AR |Epoch: 156 | Train Loss: 0.035922 | Validation_Loss: 0.008322 |
# Model: MLP_IK_AR |Epoch: 157 | Train Loss: 0.035921 | Validation_Loss: 0.008314 |
# Model: MLP_IK_AR |Epoch: 158 | Train Loss: 0.035878 | Validation_Loss: 0.008302 |
# Model: MLP_IK_AR |Epoch: 159 | Train Loss: 0.035850 | Validation_Loss: 0.008289 |
# Model: MLP_IK_AR |Epoch: 160 | Train Loss: 0.035808 | Validation_Loss: 0.008271 |
# Model: MLP_IK_AR |Epoch: 161 | Train Loss: 0.035803 | Validation_Loss: 0.008263 |
# Model: MLP_IK_AR |Epoch: 162 | Train Loss: 0.035767 | Validation_Loss: 0.008251 |
# Model: MLP_IK_AR |Epoch: 163 | Train Loss: 0.035740 | Validation_Loss: 0.008238 |
# Model: MLP_IK_AR |Epoch: 164 | Train Loss: 0.035708 | Validation_Loss: 0.008227 |
# Model: MLP_IK_AR |Epoch: 165 | Train Loss: 0.035680 | Validation_Loss: 0.008214 |
# Model: MLP_IK_AR |Epoch: 166 | Train Loss: 0.035648 | Validation_Loss: 0.008204 |
# Model: MLP_IK_AR |Epoch: 167 | Train Loss: 0.035620 | Validation_Loss: 0.008193 |
# Model: MLP_IK_AR |Epoch: 168 | Train Loss: 0.035589 | Validation_Loss: 0.008180 |
# Model: MLP_IK_AR |Epoch: 169 | Train Loss: 0.035562 | Validation_Loss: 0.008169 |
# Model: MLP_IK_AR |Epoch: 170 | Train Loss: 0.035533 | Validation_Loss: 0.008157 |
# Model: MLP_IK_AR |Epoch: 171 | Train Loss: 0.035507 | Validation_Loss: 0.008146 |
# Model: MLP_IK_AR |Epoch: 172 | Train Loss: 0.035470 | Validation_Loss: 0.008134 |
# Model: MLP_IK_AR |Epoch: 173 | Train Loss: 0.035453 | Validation_Loss: 0.008122 |
# Model: MLP_IK_AR |Epoch: 174 | Train Loss: 0.035428 | Validation_Loss: 0.008110 |
# Model: MLP_IK_AR |Epoch: 175 | Train Loss: 0.035397 | Validation_Loss: 0.008100 |
# Model: MLP_IK_AR |Epoch: 176 | Train Loss: 0.035369 | Validation_Loss: 0.008089 |
# Model: MLP_IK_AR |Epoch: 177 | Train Loss: 0.035344 | Validation_Loss: 0.008077 |
# Model: MLP_IK_AR |Epoch: 178 | Train Loss: 0.035315 | Validation_Loss: 0.008066 |
# Model: MLP_IK_AR |Epoch: 179 | Train Loss: 0.035264 | Validation_Loss: 0.008051 |
# Model: MLP_IK_AR |Epoch: 180 | Train Loss: 0.035264 | Validation_Loss: 0.008039 |
# Model: MLP_IK_AR |Epoch: 181 | Train Loss: 0.035231 | Validation_Loss: 0.008028 |
# Model: MLP_IK_AR |Epoch: 182 | Train Loss: 0.035208 | Validation_Loss: 0.008015 |
# Model: MLP_IK_AR |Epoch: 183 | Train Loss: 0.035175 | Validation_Loss: 0.008005 |
# Model: MLP_IK_AR |Epoch: 184 | Train Loss: 0.035122 | Validation_Loss: 0.007989 |
# Model: MLP_IK_AR |Epoch: 185 | Train Loss: 0.035138 | Validation_Loss: 0.007980 |
# Model: MLP_IK_AR |Epoch: 186 | Train Loss: 0.035093 | Validation_Loss: 0.007966 |
# Model: MLP_IK_AR |Epoch: 187 | Train Loss: 0.035068 | Validation_Loss: 0.007957 |
# Model: MLP_IK_AR |Epoch: 188 | Train Loss: 0.035036 | Validation_Loss: 0.007944 |
# Model: MLP_IK_AR |Epoch: 189 | Train Loss: 0.035003 | Validation_Loss: 0.007932 |
# Model: MLP_IK_AR |Epoch: 190 | Train Loss: 0.034987 | Validation_Loss: 0.007921 |
# Model: MLP_IK_AR |Epoch: 191 | Train Loss: 0.034964 | Validation_Loss: 0.007909 |
# Model: MLP_IK_AR |Epoch: 192 | Train Loss: 0.034927 | Validation_Loss: 0.007896 |
# Model: MLP_IK_AR |Epoch: 193 | Train Loss: 0.034911 | Validation_Loss: 0.007886 |
# Model: MLP_IK_AR |Epoch: 194 | Train Loss: 0.034876 | Validation_Loss: 0.007874 |
# Model: MLP_IK_AR |Epoch: 195 | Train Loss: 0.034857 | Validation_Loss: 0.007864 |
# Model: MLP_IK_AR |Epoch: 196 | Train Loss: 0.034826 | Validation_Loss: 0.007852 |
# Model: MLP_IK_AR |Epoch: 197 | Train Loss: 0.034775 | Validation_Loss: 0.007839 |
# Model: MLP_IK_AR |Epoch: 198 | Train Loss: 0.034776 | Validation_Loss: 0.007830 |
# Model: MLP_IK_AR |Epoch: 199 | Train Loss: 0.034750 | Validation_Loss: 0.007820 |
# Model: MLP_IK_AR |Epoch: 200 | Train Loss: 0.034721 | Validation_Loss: 0.007809 |
# Model: MLP_IK_AR |Epoch: 201 | Train Loss: 0.034701 | Validation_Loss: 0.007800 |
# Model: MLP_IK_AR |Epoch: 202 | Train Loss: 0.034667 | Validation_Loss: 0.007787 |
# Model: MLP_IK_AR |Epoch: 203 | Train Loss: 0.034646 | Validation_Loss: 0.007779 |
# Model: MLP_IK_AR |Epoch: 204 | Train Loss: 0.034609 | Validation_Loss: 0.007765 |
# Model: MLP_IK_AR |Epoch: 205 | Train Loss: 0.034588 | Validation_Loss: 0.007757 |
# Model: MLP_IK_AR |Epoch: 206 | Train Loss: 0.034557 | Validation_Loss: 0.007742 |
# Model: MLP_IK_AR |Epoch: 207 | Train Loss: 0.034535 | Validation_Loss: 0.007733 |
# Model: MLP_IK_AR |Epoch: 208 | Train Loss: 0.034503 | Validation_Loss: 0.007720 |
# Model: MLP_IK_AR |Epoch: 209 | Train Loss: 0.034484 | Validation_Loss: 0.007711 |
# Model: MLP_IK_AR |Epoch: 210 | Train Loss: 0.034453 | Validation_Loss: 0.007696 |
# Model: MLP_IK_AR |Epoch: 211 | Train Loss: 0.034403 | Validation_Loss: 0.007683 |
# Model: MLP_IK_AR |Epoch: 212 | Train Loss: 0.034402 | Validation_Loss: 0.007669 |
# Model: MLP_IK_AR |Epoch: 213 | Train Loss: 0.034383 | Validation_Loss: 0.007660 |
# Model: MLP_IK_AR |Epoch: 214 | Train Loss: 0.034342 | Validation_Loss: 0.007642 |
# Model: MLP_IK_AR |Epoch: 215 | Train Loss: 0.034325 | Validation_Loss: 0.007634 |
# Model: MLP_IK_AR |Epoch: 216 | Train Loss: 0.034293 | Validation_Loss: 0.007615 |
# Model: MLP_IK_AR |Epoch: 217 | Train Loss: 0.034273 | Validation_Loss: 0.007602 |
# Model: MLP_IK_AR |Epoch: 218 | Train Loss: 0.034231 | Validation_Loss: 0.007580 |
# Model: MLP_IK_AR |Epoch: 219 | Train Loss: 0.034226 | Validation_Loss: 0.007570 |
# Model: MLP_IK_AR |Epoch: 220 | Train Loss: 0.034176 | Validation_Loss: 0.007551 |
# Model: MLP_IK_AR |Epoch: 221 | Train Loss: 0.034172 | Validation_Loss: 0.007543 |
# Model: MLP_IK_AR |Epoch: 222 | Train Loss: 0.034129 | Validation_Loss: 0.007526 |
# Model: MLP_IK_AR |Epoch: 223 | Train Loss: 0.034111 | Validation_Loss: 0.007516 |
# Model: MLP_IK_AR |Epoch: 224 | Train Loss: 0.034077 | Validation_Loss: 0.007500 |
# Model: MLP_IK_AR |Epoch: 225 | Train Loss: 0.034036 | Validation_Loss: 0.007487 |
# Model: MLP_IK_AR |Epoch: 226 | Train Loss: 0.034029 | Validation_Loss: 0.007471 |
# Model: MLP_IK_AR |Epoch: 227 | Train Loss: 0.034009 | Validation_Loss: 0.007465 |
# Model: MLP_IK_AR |Epoch: 228 | Train Loss: 0.033971 | Validation_Loss: 0.007449 |
# Model: MLP_IK_AR |Epoch: 229 | Train Loss: 0.033930 | Validation_Loss: 0.007437 |
# Model: MLP_IK_AR |Epoch: 230 | Train Loss: 0.033920 | Validation_Loss: 0.007420 |
# Model: MLP_IK_AR |Epoch: 231 | Train Loss: 0.033904 | Validation_Loss: 0.007416 |
# Model: MLP_IK_AR |Epoch: 232 | Train Loss: 0.033862 | Validation_Loss: 0.007400 |
# Model: MLP_IK_AR |Epoch: 233 | Train Loss: 0.033848 | Validation_Loss: 0.007394 |
# Model: MLP_IK_AR |Epoch: 234 | Train Loss: 0.033808 | Validation_Loss: 0.007378 |
# Model: MLP_IK_AR |Epoch: 235 | Train Loss: 0.033776 | Validation_Loss: 0.007368 |
# Model: MLP_IK_AR |Epoch: 236 | Train Loss: 0.033756 | Validation_Loss: 0.007350 |
# Model: MLP_IK_AR |Epoch: 237 | Train Loss: 0.033745 | Validation_Loss: 0.007348 |
# Model: MLP_IK_AR |Epoch: 238 | Train Loss: 0.033701 | Validation_Loss: 0.007334 |
# Model: MLP_IK_AR |Epoch: 239 | Train Loss: 0.033683 | Validation_Loss: 0.007328 |
# Model: MLP_IK_AR |Epoch: 240 | Train Loss: 0.033644 | Validation_Loss: 0.007312 |
# Model: MLP_IK_AR |Epoch: 241 | Train Loss: 0.033609 | Validation_Loss: 0.007302 |
# Model: MLP_IK_AR |Epoch: 242 | Train Loss: 0.033593 | Validation_Loss: 0.007285 |
# Model: MLP_IK_AR |Epoch: 243 | Train Loss: 0.033581 | Validation_Loss: 0.007283 |
# Model: MLP_IK_AR |Epoch: 244 | Train Loss: 0.033542 | Validation_Loss: 0.007265 |
# Model: MLP_IK_AR |Epoch: 245 | Train Loss: 0.033524 | Validation_Loss: 0.007262 |
# Model: MLP_IK_AR |Epoch: 246 | Train Loss: 0.033487 | Validation_Loss: 0.007243 |
# Model: MLP_IK_AR |Epoch: 247 | Train Loss: 0.033475 | Validation_Loss: 0.007240 |
# Model: MLP_IK_AR |Epoch: 248 | Train Loss: 0.033432 | Validation_Loss: 0.007222 |
# Model: MLP_IK_AR |Epoch: 249 | Train Loss: 0.033416 | Validation_Loss: 0.007221 |
# Model: MLP_IK_AR |Epoch: 250 | Train Loss: 0.033376 | Validation_Loss: 0.007203 |
# Model: MLP_IK_AR |Epoch: 251 | Train Loss: 0.033370 | Validation_Loss: 0.007198 |
# Model: MLP_IK_AR |Epoch: 252 | Train Loss: 0.033330 | Validation_Loss: 0.007181 |
# Model: MLP_IK_AR |Epoch: 253 | Train Loss: 0.033315 | Validation_Loss: 0.007177 |
# Model: MLP_IK_AR |Epoch: 254 | Train Loss: 0.033273 | Validation_Loss: 0.007160 |
# Model: MLP_IK_AR |Epoch: 255 | Train Loss: 0.033257 | Validation_Loss: 0.007154 |
# Model: MLP_IK_AR |Epoch: 256 | Train Loss: 0.033223 | Validation_Loss: 0.007137 |
# Model: MLP_IK_AR |Epoch: 257 | Train Loss: 0.033208 | Validation_Loss: 0.007130 |
# Model: MLP_IK_AR |Epoch: 258 | Train Loss: 0.033170 | Validation_Loss: 0.007112 |
# Model: MLP_IK_AR |Epoch: 259 | Train Loss: 0.033157 | Validation_Loss: 0.007107 |
# Model: MLP_IK_AR |Epoch: 260 | Train Loss: 0.033125 | Validation_Loss: 0.007090 |
# Model: MLP_IK_AR |Epoch: 261 | Train Loss: 0.033103 | Validation_Loss: 0.007085 |
# Model: MLP_IK_AR |Epoch: 262 | Train Loss: 0.033061 | Validation_Loss: 0.007064 |
# Model: MLP_IK_AR |Epoch: 263 | Train Loss: 0.033052 | Validation_Loss: 0.007059 |
# Model: MLP_IK_AR |Epoch: 264 | Train Loss: 0.033016 | Validation_Loss: 0.007040 |
# Model: MLP_IK_AR |Epoch: 265 | Train Loss: 0.033001 | Validation_Loss: 0.007031 |
# Model: MLP_IK_AR |Epoch: 266 | Train Loss: 0.032959 | Validation_Loss: 0.007016 |
# Model: MLP_IK_AR |Epoch: 267 | Train Loss: 0.032958 | Validation_Loss: 0.007011 |
# Model: MLP_IK_AR |Epoch: 268 | Train Loss: 0.032908 | Validation_Loss: 0.006996 |
# Model: MLP_IK_AR |Epoch: 269 | Train Loss: 0.032900 | Validation_Loss: 0.006986 |
# Model: MLP_IK_AR |Epoch: 270 | Train Loss: 0.032862 | Validation_Loss: 0.006970 |
# Model: MLP_IK_AR |Epoch: 271 | Train Loss: 0.032849 | Validation_Loss: 0.006964 |
# Model: MLP_IK_AR |Epoch: 272 | Train Loss: 0.032808 | Validation_Loss: 0.006950 |
# Model: MLP_IK_AR |Epoch: 273 | Train Loss: 0.032784 | Validation_Loss: 0.006943 |
# Model: MLP_IK_AR |Epoch: 274 | Train Loss: 0.032752 | Validation_Loss: 0.006921 |
# Model: MLP_IK_AR |Epoch: 275 | Train Loss: 0.032742 | Validation_Loss: 0.006916 |
# Model: MLP_IK_AR |Epoch: 276 | Train Loss: 0.032705 | Validation_Loss: 0.006901 |
# Model: MLP_IK_AR |Epoch: 277 | Train Loss: 0.032677 | Validation_Loss: 0.006891 |
# Model: MLP_IK_AR |Epoch: 278 | Train Loss: 0.032647 | Validation_Loss: 0.006873 |
# Model: MLP_IK_AR |Epoch: 279 | Train Loss: 0.032634 | Validation_Loss: 0.006864 |
# Model: MLP_IK_AR |Epoch: 280 | Train Loss: 0.032608 | Validation_Loss: 0.006847 |
# Model: MLP_IK_AR |Epoch: 281 | Train Loss: 0.032572 | Validation_Loss: 0.006842 |
# Model: MLP_IK_AR |Epoch: 282 | Train Loss: 0.032547 | Validation_Loss: 0.006823 |
# Model: MLP_IK_AR |Epoch: 283 | Train Loss: 0.032530 | Validation_Loss: 0.006818 |
# Model: MLP_IK_AR |Epoch: 284 | Train Loss: 0.032494 | Validation_Loss: 0.006805 |
# Model: MLP_IK_AR |Epoch: 285 | Train Loss: 0.032473 | Validation_Loss: 0.006795 |
# Model: MLP_IK_AR |Epoch: 286 | Train Loss: 0.032447 | Validation_Loss: 0.006781 |
# Model: MLP_IK_AR |Epoch: 287 | Train Loss: 0.032422 | Validation_Loss: 0.006772 |
# Model: MLP_IK_AR |Epoch: 288 | Train Loss: 0.032392 | Validation_Loss: 0.006761 |
# Model: MLP_IK_AR |Epoch: 289 | Train Loss: 0.032371 | Validation_Loss: 0.006744 |
# Model: MLP_IK_AR |Epoch: 290 | Train Loss: 0.032362 | Validation_Loss: 0.006740 |
# Model: MLP_IK_AR |Epoch: 291 | Train Loss: 0.032319 | Validation_Loss: 0.006723 |
# Model: MLP_IK_AR |Epoch: 292 | Train Loss: 0.032303 | Validation_Loss: 0.006712 |
# Model: MLP_IK_AR |Epoch: 293 | Train Loss: 0.032276 | Validation_Loss: 0.006699 |
# Model: MLP_IK_AR |Epoch: 294 | Train Loss: 0.032248 | Validation_Loss: 0.006693 |
# Model: MLP_IK_AR |Epoch: 295 | Train Loss: 0.032221 | Validation_Loss: 0.006675 |
# Model: MLP_IK_AR |Epoch: 296 | Train Loss: 0.032207 | Validation_Loss: 0.006670 |
# Model: MLP_IK_AR |Epoch: 297 | Train Loss: 0.032167 | Validation_Loss: 0.006656 |
# Model: MLP_IK_AR |Epoch: 298 | Train Loss: 0.032148 | Validation_Loss: 0.006643 |
# Model: MLP_IK_AR |Epoch: 299 | Train Loss: 0.032127 | Validation_Loss: 0.006629 |
# Model: MLP_IK_AR |Epoch: 300 | Train Loss: 0.032095 | Validation_Loss: 0.006621 |
# Model: MLP_IK_AR |Epoch: 301 | Train Loss: 0.032066 | Validation_Loss: 0.006603 |
# Model: MLP_IK_AR |Epoch: 302 | Train Loss: 0.032051 | Validation_Loss: 0.006597 |
# Model: MLP_IK_AR |Epoch: 303 | Train Loss: 0.032024 | Validation_Loss: 0.006583 |
# Model: MLP_IK_AR |Epoch: 304 | Train Loss: 0.031991 | Validation_Loss: 0.006572 |
# Model: MLP_IK_AR |Epoch: 305 | Train Loss: 0.031973 | Validation_Loss: 0.006562 |
# Model: MLP_IK_AR |Epoch: 306 | Train Loss: 0.031948 | Validation_Loss: 0.006545 |
# Model: MLP_IK_AR |Epoch: 307 | Train Loss: 0.031924 | Validation_Loss: 0.006534 |
# Model: MLP_IK_AR |Epoch: 308 | Train Loss: 0.031897 | Validation_Loss: 0.006525 |
# Model: MLP_IK_AR |Epoch: 309 | Train Loss: 0.031873 | Validation_Loss: 0.006509 |
# Model: MLP_IK_AR |Epoch: 310 | Train Loss: 0.031849 | Validation_Loss: 0.006500 |
# Model: MLP_IK_AR |Epoch: 311 | Train Loss: 0.031831 | Validation_Loss: 0.006490 |
# Model: MLP_IK_AR |Epoch: 312 | Train Loss: 0.031800 | Validation_Loss: 0.006476 |
# Model: MLP_IK_AR |Epoch: 313 | Train Loss: 0.031777 | Validation_Loss: 0.006470 |
# Model: MLP_IK_AR |Epoch: 314 | Train Loss: 0.031753 | Validation_Loss: 0.006455 |
# Model: MLP_IK_AR |Epoch: 315 | Train Loss: 0.031727 | Validation_Loss: 0.006442 |
# Model: MLP_IK_AR |Epoch: 316 | Train Loss: 0.031700 | Validation_Loss: 0.006433 |
# Model: MLP_IK_AR |Epoch: 317 | Train Loss: 0.031677 | Validation_Loss: 0.006415 |
# Model: MLP_IK_AR |Epoch: 318 | Train Loss: 0.031658 | Validation_Loss: 0.006412 |
# Model: MLP_IK_AR |Epoch: 319 | Train Loss: 0.031624 | Validation_Loss: 0.006391 |
# Model: MLP_IK_AR |Epoch: 320 | Train Loss: 0.031614 | Validation_Loss: 0.006384 |
# Model: MLP_IK_AR |Epoch: 321 | Train Loss: 0.031570 | Validation_Loss: 0.006371 |
# Model: MLP_IK_AR |Epoch: 322 | Train Loss: 0.031560 | Validation_Loss: 0.006359 |
# Model: MLP_IK_AR |Epoch: 323 | Train Loss: 0.031533 | Validation_Loss: 0.006344 |
# Model: MLP_IK_AR |Epoch: 324 | Train Loss: 0.031503 | Validation_Loss: 0.006335 |
# Model: MLP_IK_AR |Epoch: 325 | Train Loss: 0.031478 | Validation_Loss: 0.006324 |
# Model: MLP_IK_AR |Epoch: 326 | Train Loss: 0.031455 | Validation_Loss: 0.006311 |
# Model: MLP_IK_AR |Epoch: 327 | Train Loss: 0.031441 | Validation_Loss: 0.006299 |
# Model: MLP_IK_AR |Epoch: 328 | Train Loss: 0.031408 | Validation_Loss: 0.006288 |
# Model: MLP_IK_AR |Epoch: 329 | Train Loss: 0.031388 | Validation_Loss: 0.006279 |
# Model: MLP_IK_AR |Epoch: 330 | Train Loss: 0.031365 | Validation_Loss: 0.006264 |
# Model: MLP_IK_AR |Epoch: 331 | Train Loss: 0.031349 | Validation_Loss: 0.006259 |
# Model: MLP_IK_AR |Epoch: 332 | Train Loss: 0.031308 | Validation_Loss: 0.006243 |
# Model: MLP_IK_AR |Epoch: 333 | Train Loss: 0.031287 | Validation_Loss: 0.006233 |
# Model: MLP_IK_AR |Epoch: 334 | Train Loss: 0.031276 | Validation_Loss: 0.006226 |
# Model: MLP_IK_AR |Epoch: 335 | Train Loss: 0.031240 | Validation_Loss: 0.006209 |
# Model: MLP_IK_AR |Epoch: 336 | Train Loss: 0.031218 | Validation_Loss: 0.006202 |
# Model: MLP_IK_AR |Epoch: 337 | Train Loss: 0.031190 | Validation_Loss: 0.006187 |
# Model: MLP_IK_AR |Epoch: 338 | Train Loss: 0.031177 | Validation_Loss: 0.006177 |
# Model: MLP_IK_AR |Epoch: 339 | Train Loss: 0.031142 | Validation_Loss: 0.006165 |
# Model: MLP_IK_AR |Epoch: 340 | Train Loss: 0.031122 | Validation_Loss: 0.006156 |
# Model: MLP_IK_AR |Epoch: 341 | Train Loss: 0.031102 | Validation_Loss: 0.006142 |
# Model: MLP_IK_AR |Epoch: 342 | Train Loss: 0.031071 | Validation_Loss: 0.006133 |
# Model: MLP_IK_AR |Epoch: 343 | Train Loss: 0.031045 | Validation_Loss: 0.006121 |
# Model: MLP_IK_AR |Epoch: 344 | Train Loss: 0.031028 | Validation_Loss: 0.006110 |
# Model: MLP_IK_AR |Epoch: 345 | Train Loss: 0.030998 | Validation_Loss: 0.006099 |
# Model: MLP_IK_AR |Epoch: 346 | Train Loss: 0.030980 | Validation_Loss: 0.006090 |
# Model: MLP_IK_AR |Epoch: 347 | Train Loss: 0.030961 | Validation_Loss: 0.006080 |
# Model: MLP_IK_AR |Epoch: 348 | Train Loss: 0.030929 | Validation_Loss: 0.006071 |
# Model: MLP_IK_AR |Epoch: 349 | Train Loss: 0.030911 | Validation_Loss: 0.006061 |
# Model: MLP_IK_AR |Epoch: 350 | Train Loss: 0.030888 | Validation_Loss: 0.006043 |
# Model: MLP_IK_AR |Epoch: 351 | Train Loss: 0.030867 | Validation_Loss: 0.006041 |
# Model: MLP_IK_AR |Epoch: 352 | Train Loss: 0.030834 | Validation_Loss: 0.006027 |
# Model: MLP_IK_AR |Epoch: 353 | Train Loss: 0.030830 | Validation_Loss: 0.006024 |
# Model: MLP_IK_AR |Epoch: 354 | Train Loss: 0.030793 | Validation_Loss: 0.006010 |
# Model: MLP_IK_AR |Epoch: 355 | Train Loss: 0.030776 | Validation_Loss: 0.006003 |
# Model: MLP_IK_AR |Epoch: 356 | Train Loss: 0.030752 | Validation_Loss: 0.005995 |
# Model: MLP_IK_AR |Epoch: 357 | Train Loss: 0.030728 | Validation_Loss: 0.005984 |
# Model: MLP_IK_AR |Epoch: 358 | Train Loss: 0.030723 | Validation_Loss: 0.005977 |
# Model: MLP_IK_AR |Epoch: 359 | Train Loss: 0.030680 | Validation_Loss: 0.005966 |
# Model: MLP_IK_AR |Epoch: 360 | Train Loss: 0.030663 | Validation_Loss: 0.005958 |
# Model: MLP_IK_AR |Epoch: 361 | Train Loss: 0.030649 | Validation_Loss: 0.005945 |
# Model: MLP_IK_AR |Epoch: 362 | Train Loss: 0.030619 | Validation_Loss: 0.005937 |
# Model: MLP_IK_AR |Epoch: 363 | Train Loss: 0.030593 | Validation_Loss: 0.005922 |
# Model: MLP_IK_AR |Epoch: 364 | Train Loss: 0.030592 | Validation_Loss: 0.005915 |
# Model: MLP_IK_AR |Epoch: 365 | Train Loss: 0.030551 | Validation_Loss: 0.005906 |
# Model: MLP_IK_AR |Epoch: 366 | Train Loss: 0.030532 | Validation_Loss: 0.005896 |
# Model: MLP_IK_AR |Epoch: 367 | Train Loss: 0.030515 | Validation_Loss: 0.005888 |
# Model: MLP_IK_AR |Epoch: 368 | Train Loss: 0.030484 | Validation_Loss: 0.005882 |
# Model: MLP_IK_AR |Epoch: 369 | Train Loss: 0.030465 | Validation_Loss: 0.005872 |
# Model: MLP_IK_AR |Epoch: 370 | Train Loss: 0.030450 | Validation_Loss: 0.005866 |
# Model: MLP_IK_AR |Epoch: 371 | Train Loss: 0.030414 | Validation_Loss: 0.005852 |
# Model: MLP_IK_AR |Epoch: 372 | Train Loss: 0.030412 | Validation_Loss: 0.005848 |
# Model: MLP_IK_AR |Epoch: 373 | Train Loss: 0.030376 | Validation_Loss: 0.005843 |
# Model: MLP_IK_AR |Epoch: 374 | Train Loss: 0.030363 | Validation_Loss: 0.005834 |
# Model: MLP_IK_AR |Epoch: 375 | Train Loss: 0.030348 | Validation_Loss: 0.005815 |
# Model: MLP_IK_AR |Epoch: 376 | Train Loss: 0.030323 | Validation_Loss: 0.005809 |
# Model: MLP_IK_AR |Epoch: 377 | Train Loss: 0.030293 | Validation_Loss: 0.005799 |
# Model: MLP_IK_AR |Epoch: 378 | Train Loss: 0.030287 | Validation_Loss: 0.005787 |
# Model: MLP_IK_AR |Epoch: 379 | Train Loss: 0.030252 | Validation_Loss: 0.005780 |
# Model: MLP_IK_AR |Epoch: 380 | Train Loss: 0.030237 | Validation_Loss: 0.005777 |
# Model: MLP_IK_AR |Epoch: 381 | Train Loss: 0.030212 | Validation_Loss: 0.005762 |
# Model: MLP_IK_AR |Epoch: 382 | Train Loss: 0.030194 | Validation_Loss: 0.005760 |
# Model: MLP_IK_AR |Epoch: 383 | Train Loss: 0.030168 | Validation_Loss: 0.005750 |
# Model: MLP_IK_AR |Epoch: 384 | Train Loss: 0.030147 | Validation_Loss: 0.005746 |
# Model: MLP_IK_AR |Epoch: 385 | Train Loss: 0.030127 | Validation_Loss: 0.005732 |
# Model: MLP_IK_AR |Epoch: 386 | Train Loss: 0.030105 | Validation_Loss: 0.005732 |
# Model: MLP_IK_AR |Epoch: 387 | Train Loss: 0.030081 | Validation_Loss: 0.005716 |
# Model: MLP_IK_AR |Epoch: 388 | Train Loss: 0.030056 | Validation_Loss: 0.005712 |
# Model: MLP_IK_AR |Epoch: 389 | Train Loss: 0.030044 | Validation_Loss: 0.005701 |
# Model: MLP_IK_AR |Epoch: 390 | Train Loss: 0.030025 | Validation_Loss: 0.005697 |
# Model: MLP_IK_AR |Epoch: 391 | Train Loss: 0.029984 | Validation_Loss: 0.005686 |
# Model: MLP_IK_AR |Epoch: 392 | Train Loss: 0.029988 | Validation_Loss: 0.005681 |
# Model: MLP_IK_AR |Epoch: 393 | Train Loss: 0.029955 | Validation_Loss: 0.005673 |
# Model: MLP_IK_AR |Epoch: 394 | Train Loss: 0.029937 | Validation_Loss: 0.005671 |
# Model: MLP_IK_AR |Epoch: 395 | Train Loss: 0.029914 | Validation_Loss: 0.005660 |
# Model: MLP_IK_AR |Epoch: 396 | Train Loss: 0.029900 | Validation_Loss: 0.005648 |
# Model: MLP_IK_AR |Epoch: 397 | Train Loss: 0.029874 | Validation_Loss: 0.005644 |
# Model: MLP_IK_AR |Epoch: 398 | Train Loss: 0.029840 | Validation_Loss: 0.005636 |
# Model: MLP_IK_AR |Epoch: 399 | Train Loss: 0.029831 | Validation_Loss: 0.005623 |
# Model: MLP_IK_AR |Epoch: 400 | Train Loss: 0.029814 | Validation_Loss: 0.005616 |
# Model: MLP_IK_AR |Epoch: 401 | Train Loss: 0.029789 | Validation_Loss: 0.005611 |
# Model: MLP_IK_AR |Epoch: 402 | Train Loss: 0.029756 | Validation_Loss: 0.005607 |
# Model: MLP_IK_AR |Epoch: 403 | Train Loss: 0.029759 | Validation_Loss: 0.005599 |
# Model: MLP_IK_AR |Epoch: 404 | Train Loss: 0.029712 | Validation_Loss: 0.005590 |
# Model: MLP_IK_AR |Epoch: 405 | Train Loss: 0.029692 | Validation_Loss: 0.005589 |
# Model: MLP_IK_AR |Epoch: 406 | Train Loss: 0.029685 | Validation_Loss: 0.005576 |
# Model: MLP_IK_AR |Epoch: 407 | Train Loss: 0.029665 | Validation_Loss: 0.005577 |
# Model: MLP_IK_AR |Epoch: 408 | Train Loss: 0.029627 | Validation_Loss: 0.005570 |
# Model: MLP_IK_AR |Epoch: 409 | Train Loss: 0.029617 | Validation_Loss: 0.005566 |
# Model: MLP_IK_AR |Epoch: 410 | Train Loss: 0.029608 | Validation_Loss: 0.005562 |
# Model: MLP_IK_AR |Epoch: 411 | Train Loss: 0.029567 | Validation_Loss: 0.005553 |
# Model: MLP_IK_AR |Epoch: 412 | Train Loss: 0.029558 | Validation_Loss: 0.005553 |
# Model: MLP_IK_AR |Epoch: 413 | Train Loss: 0.029539 | Validation_Loss: 0.005554 |
# Model: MLP_IK_AR |Epoch: 414 | Train Loss: 0.029524 | Validation_Loss: 0.005541 |
# Model: MLP_IK_AR |Epoch: 415 | Train Loss: 0.029506 | Validation_Loss: 0.005546 |
# Model: MLP_IK_AR |Epoch: 416 | Train Loss: 0.029472 | Validation_Loss: 0.005539 |
# Model: MLP_IK_AR |Epoch: 417 | Train Loss: 0.029462 | Validation_Loss: 0.005531 |
# Model: MLP_IK_AR |Epoch: 418 | Train Loss: 0.029452 | Validation_Loss: 0.005528 |
# Model: MLP_IK_AR |Epoch: 419 | Train Loss: 0.029422 | Validation_Loss: 0.005527 |
# Model: MLP_IK_AR |Epoch: 420 | Train Loss: 0.029406 | Validation_Loss: 0.005523 |
# Model: MLP_IK_AR |Epoch: 421 | Train Loss: 0.029398 | Validation_Loss: 0.005522 |
# Model: MLP_IK_AR |Epoch: 422 | Train Loss: 0.029383 | Validation_Loss: 0.005518 |
# Model: MLP_IK_AR |Epoch: 423 | Train Loss: 0.029358 | Validation_Loss: 0.005520 |
# Model: MLP_IK_AR |Epoch: 424 | Train Loss: 0.029329 | Validation_Loss: 0.005512 |
# Model: MLP_IK_AR |Epoch: 425 | Train Loss: 0.029331 | Validation_Loss: 0.005509 |
# Model: MLP_IK_AR |Epoch: 426 | Train Loss: 0.029307 | Validation_Loss: 0.005508 |
# Model: MLP_IK_AR |Epoch: 427 | Train Loss: 0.029282 | Validation_Loss: 0.005505 |
# Model: MLP_IK_AR |Epoch: 428 | Train Loss: 0.029260 | Validation_Loss: 0.005507 |
# Model: MLP_IK_AR |Epoch: 429 | Train Loss: 0.029264 | Validation_Loss: 0.005508 |
# Model: MLP_IK_AR |Epoch: 430 | Train Loss: 0.029231 | Validation_Loss: 0.005508 |
# Model: MLP_IK_AR |Epoch: 431 | Train Loss: 0.029217 | Validation_Loss: 0.005504 |
# Model: MLP_IK_AR |Epoch: 432 | Train Loss: 0.029198 | Validation_Loss: 0.005501 |
# Model: MLP_IK_AR |Epoch: 433 | Train Loss: 0.029183 | Validation_Loss: 0.005501 |
# Model: MLP_IK_AR |Epoch: 434 | Train Loss: 0.029164 | Validation_Loss: 0.005496 |
# Model: MLP_IK_AR |Epoch: 435 | Train Loss: 0.029152 | Validation_Loss: 0.005500 |
# Model: MLP_IK_AR |Epoch: 436 | Train Loss: 0.029132 | Validation_Loss: 0.005499 |
# Model: MLP_IK_AR |Epoch: 437 | Train Loss: 0.029119 | Validation_Loss: 0.005500 |
# Model: MLP_IK_AR |Epoch: 438 | Train Loss: 0.029100 | Validation_Loss: 0.005496 |
# Model: MLP_IK_AR |Epoch: 439 | Train Loss: 0.029084 | Validation_Loss: 0.005494 |
# Model: MLP_IK_AR |Epoch: 440 | Train Loss: 0.029070 | Validation_Loss: 0.005491 |
# Model: MLP_IK_AR |Epoch: 441 | Train Loss: 0.029059 | Validation_Loss: 0.005490 |
# Model: MLP_IK_AR |Epoch: 442 | Train Loss: 0.029040 | Validation_Loss: 0.005486 |
# Model: MLP_IK_AR |Epoch: 443 | Train Loss: 0.029024 | Validation_Loss: 0.005488 |
# Model: MLP_IK_AR |Epoch: 444 | Train Loss: 0.029002 | Validation_Loss: 0.005490 |
# Model: MLP_IK_AR |Epoch: 445 | Train Loss: 0.028991 | Validation_Loss: 0.005485 |
# Model: MLP_IK_AR |Epoch: 446 | Train Loss: 0.028991 | Validation_Loss: 0.005489 |
# Model: MLP_IK_AR |Epoch: 447 | Train Loss: 0.028954 | Validation_Loss: 0.005482 |
# Model: MLP_IK_AR |Epoch: 448 | Train Loss: 0.028958 | Validation_Loss: 0.005491 |
# Model: MLP_IK_AR |Epoch: 449 | Train Loss: 0.028926 | Validation_Loss: 0.005475 |
# Model: MLP_IK_AR |Epoch: 450 | Train Loss: 0.028923 | Validation_Loss: 0.005487 |
# Model: MLP_IK_AR |Epoch: 451 | Train Loss: 0.028903 | Validation_Loss: 0.005478 |
# Model: MLP_IK_AR |Epoch: 452 | Train Loss: 0.028899 | Validation_Loss: 0.005489 |
# Model: MLP_IK_AR |Epoch: 453 | Train Loss: 0.028862 | Validation_Loss: 0.005468 |
# Model: MLP_IK_AR |Epoch: 454 | Train Loss: 0.028878 | Validation_Loss: 0.005489 |
# Model: MLP_IK_AR |Epoch: 455 | Train Loss: 0.028839 | Validation_Loss: 0.005473 |
# Model: MLP_IK_AR |Epoch: 456 | Train Loss: 0.028848 | Validation_Loss: 0.005486 |
# Model: MLP_IK_AR |Epoch: 457 | Train Loss: 0.028805 | Validation_Loss: 0.005468 |
# Model: MLP_IK_AR |Epoch: 458 | Train Loss: 0.028815 | Validation_Loss: 0.005474 |
# Model: MLP_IK_AR |Epoch: 459 | Train Loss: 0.028789 | Validation_Loss: 0.005458 |
# Model: MLP_IK_AR |Epoch: 460 | Train Loss: 0.028787 | Validation_Loss: 0.005470 |
# Model: MLP_IK_AR |Epoch: 461 | Train Loss: 0.028747 | Validation_Loss: 0.005454 |
# Model: MLP_IK_AR |Epoch: 462 | Train Loss: 0.028758 | Validation_Loss: 0.005469 |
# Model: MLP_IK_AR |Epoch: 463 | Train Loss: 0.028729 | Validation_Loss: 0.005451 |
# Model: MLP_IK_AR |Epoch: 464 | Train Loss: 0.028737 | Validation_Loss: 0.005465 |
# Model: MLP_IK_AR |Epoch: 465 | Train Loss: 0.028697 | Validation_Loss: 0.005442 |
# Model: MLP_IK_AR |Epoch: 466 | Train Loss: 0.028715 | Validation_Loss: 0.005460 |
# Model: MLP_IK_AR |Epoch: 467 | Train Loss: 0.028668 | Validation_Loss: 0.005436 |
# Model: MLP_IK_AR |Epoch: 468 | Train Loss: 0.028682 | Validation_Loss: 0.005451 |
# Model: MLP_IK_AR |Epoch: 469 | Train Loss: 0.028644 | Validation_Loss: 0.005431 |
# Model: MLP_IK_AR |Epoch: 470 | Train Loss: 0.028665 | Validation_Loss: 0.005448 |
# Model: MLP_IK_AR |Epoch: 471 | Train Loss: 0.028611 | Validation_Loss: 0.005426 |
# Model: MLP_IK_AR |Epoch: 472 | Train Loss: 0.028644 | Validation_Loss: 0.005442 |
# Model: MLP_IK_AR |Epoch: 473 | Train Loss: 0.028587 | Validation_Loss: 0.005416 |
# Model: MLP_IK_AR |Epoch: 474 | Train Loss: 0.028613 | Validation_Loss: 0.005433 |
# Model: MLP_IK_AR |Epoch: 475 | Train Loss: 0.028569 | Validation_Loss: 0.005421 |
# Model: MLP_IK_AR |Epoch: 476 | Train Loss: 0.028577 | Validation_Loss: 0.005429 |
# Model: MLP_IK_AR |Epoch: 477 | Train Loss: 0.028542 | Validation_Loss: 0.005411 |
# Model: MLP_IK_AR |Epoch: 478 | Train Loss: 0.028561 | Validation_Loss: 0.005415 |
# Model: MLP_IK_AR |Epoch: 479 | Train Loss: 0.028530 | Validation_Loss: 0.005408 |
# Model: MLP_IK_AR |Epoch: 480 | Train Loss: 0.028529 | Validation_Loss: 0.005411 |
# Model: MLP_IK_AR |Epoch: 481 | Train Loss: 0.028506 | Validation_Loss: 0.005404 |
# Model: MLP_IK_AR |Epoch: 482 | Train Loss: 0.028515 | Validation_Loss: 0.005412 |
# Model: MLP_IK_AR |Epoch: 483 | Train Loss: 0.028482 | Validation_Loss: 0.005401 |
# Model: MLP_IK_AR |Epoch: 484 | Train Loss: 0.028481 | Validation_Loss: 0.005405 |
# Model: MLP_IK_AR |Epoch: 485 | Train Loss: 0.028477 | Validation_Loss: 0.005411 |
# Model: MLP_IK_AR |Epoch: 486 | Train Loss: 0.028460 | Validation_Loss: 0.005392 |
# Model: MLP_IK_AR |Epoch: 487 | Train Loss: 0.028414 | Validation_Loss: 0.005398 |
# Model: MLP_IK_AR |Epoch: 488 | Train Loss: 0.028454 | Validation_Loss: 0.005403 |
# Model: MLP_IK_AR |Epoch: 489 | Train Loss: 0.028395 | Validation_Loss: 0.005366 |
# Model: MLP_IK_AR |Epoch: 490 | Train Loss: 0.028411 | Validation_Loss: 0.005399 |
# Model: MLP_IK_AR |Epoch: 491 | Train Loss: 0.028417 | Validation_Loss: 0.005392 |
# Model: MLP_IK_AR |Epoch: 492 | Train Loss: 0.028356 | Validation_Loss: 0.005375 |
# Model: MLP_IK_AR |Epoch: 493 | Train Loss: 0.028359 | Validation_Loss: 0.005409 |
# Model: MLP_IK_AR |Epoch: 494 | Train Loss: 0.028380 | Validation_Loss: 0.005388 |
# Model: MLP_IK_AR |Epoch: 495 | Train Loss: 0.028323 | Validation_Loss: 0.005370 |
# Early Stopping Triggered

# %% [markdown]
# plot of training and validation losses

# %%
plt.figure()
#plt.plot(train_results_tf["train_loss"], label="train_loss") 
plt.plot(train_results_ar["valid_loss"], label="valid_loss")  
plt.plot(train_results_ar["train_loss"], label="train_loss")
plt.xlabel("epochs") 
plt.ylabel("MSE per epoch [m]")   
plt.title("Parallel Training and Validation Losses")
plt.legend()

# %% [markdown]
# plotting teacher forcing results

# %%
def teacherforcing_performance_plot(model : torch.nn.Module, dataloader : DataLoader, loss_fn: torch.nn, dataset_name : str) : 
    labels = [] 
    preds = [] 
    model.eval() 
    total_loss = 0.0
    with torch.inference_mode() : 
        for X , y in dataloader : 
            # forward pass 
            pred = model(X) 
            # appending 
            labels.append(y) 
            preds.append(pred) 
            # calculating the loss 
            loss = loss_fn(pred, y)
            total_loss += loss.item()

    average_loss = total_loss/len(dataloader)
    print("loss: ", average_loss) 

    labels = np.concatenate(labels, axis=0) 
    preds = np.concatenate(preds, axis=0)

    plt.figure() 
    plt.plot(labels[:,0], label='True U1') 
    plt.plot(preds[:,0], label='Predicted U1', linestyle='--')  
    plt.legend()
    plt.title(f"U_1_{dataset_name}"); 
    plt.xlabel('Sample'); 
    plt.ylabel('Value') 

    plt.figure()
    plt.plot(labels[:, 1], label='True U2')
    plt.plot(preds[:, 1],  label='Predicted U2', linestyle='--')
    plt.legend()
    plt.title(f"U_2_{dataset_name}")
    plt.xlabel('Sample')
    plt.ylabel('Value')

    plt.figure()
    plt.plot(labels[:, 2], label='True U3')
    plt.plot(preds[:, 2],  label='Predicted U3', linestyle='--')
    plt.legend()
    plt.title(f"U_3_{dataset_name}")
    plt.xlabel('Sample')
    plt.ylabel('Value')

# %%
teacherforcing_performance_plot(model=inverse_model, dataloader=train_dataloader, loss_fn=loss_fn, dataset_name="training_data")
teacherforcing_performance_plot(model=inverse_model, dataloader=valid_dataloader,  loss_fn=loss_fn, dataset_name="validation_data")
teacherforcing_performance_plot(model=inverse_model, dataloader=test_dataloader,  loss_fn=loss_fn, dataset_name="testing_data")
# Out:
# loss:  0.0072205618941372915
# loss:  0.0038191395418406874
# loss:  0.0018058460694231578

# %% [markdown]
# plotting autoregressive results

# %%
def autoregressive_performance_plot(model: torch.nn.Module, U_scaled: np.array, X_scaled: np.array,  
                                    lag_input: int, lag_state: int, ee_x_index: int, ee_y_index: int, 
                                    loss_fn: torch.nn.Module, 
                                    dataset_name: str, U1_index: int, U2_index: int, U3_index: int, 
                                    early_stopping_call = None): 

    model.eval()  

    U = torch.from_numpy(U_scaled).type(torch.float32)
    X = torch.from_numpy(X_scaled).type(torch.float32)  

    U_buffer = U.clone()

    max_lag = max(lag_input, lag_state)
     
    preds = [] 

    # initial buffer filled with ground truth 
    future_state = X[max_lag+1,ee_x_index:ee_y_index+1] 
    current_state = X[max_lag,:] 
    if lag_state == 0 : 
        past_state = X[max_lag:max_lag] 
    else : 
        past_state = X[max_lag-lag_state:max_lag,:] 
        past_state = torch.flatten(input=past_state) 
    current_input = U[max_lag,:] 
    if lag_input == 0 : 
        past_input = U[max_lag:max_lag,:]
    else : 
        past_input = U[max_lag-lag_input:max_lag,:] 
        past_input = torch.flatten(input=past_input) 

    if past_state.size(dim=0) == 0 and past_input.size(dim=0) == 0 : 
        joined_features = torch.concatenate((future_state, current_state, current_input), dim=0) 
    elif past_state.size(dim=0) != 0 and past_input.size(dim=0) == 0 : 
        joined_features = torch.concatenate((future_state, current_state, past_state, current_input), dim=0)
    elif past_state.size(dim=0) == 0 and past_input.size(dim=0) != 0 : 
        joined_features = torch.concatenate((future_state, current_state, current_input, past_input), dim=0) 
    else : 
        joined_features = torch.concatenate((future_state, current_state, past_state, current_input, past_input), dim=0)  

    with torch.inference_mode() : 

        for i in range(max_lag+1, len(U)) : 

            pred = model(joined_features.unsqueeze(0)) 
            pred = pred.squeeze(0)

            preds.append(pred) 

            U_buffer[i,:] = pred 

            if i < len(U) - 1 :
                # buffer update 
                future_state = X[i+1,ee_x_index:ee_y_index+1]
                current_state = X[i,:]
                if lag_state == 0 : 
                    past_state = X[i:i] 
                else : 
                    past_state = X[i-lag_state:i,:] 
                    past_state = torch.flatten(input=past_state)
                current_input = pred 
                if lag_input == 0 : 
                    past_input = U[i:i,:]
                else : 
                    past_input = U_buffer[i-lag_input:i,:] 
                    past_input = torch.flatten(input=past_input) 

                if past_state.size(dim=0) == 0 and past_input.size(dim=0) == 0 : 
                    joined_features = torch.concatenate((future_state, current_state, current_input), dim=0) 
                elif past_state.size(dim=0) != 0 and past_input.size(dim=0) == 0 : 
                    joined_features = torch.concatenate((future_state, current_state, past_state, current_input), dim=0)
                elif past_state.size(dim=0) == 0 and past_input.size(dim=0) != 0 : 
                    joined_features = torch.concatenate((future_state, current_state, current_input, past_input), dim=0) 
                else : 
                    joined_features = torch.concatenate((future_state, current_state, past_state, current_input, past_input), dim=0)
            
            else : 
                pass
            

    preds_tensor = torch.stack(preds, dim=0) 

    targets = U[max_lag+1:] 

    loss = loss_fn(preds_tensor, targets)  

    average_loss = loss.item()  

    print(f"Average Loss of {dataset_name}: {average_loss}")

    plt.figure() 
    plt.plot(targets[:,U1_index], label='True U1') 
    plt.plot(preds_tensor[:,U1_index], label='Predicted U1', linestyle='--')  
    plt.legend()
    plt.title(f"U_1_{dataset_name}"); 
    plt.xlabel('Sample'); 
    plt.ylabel('Value') 

    plt.figure()
    plt.plot(targets[:, U2_index], label='True U2')
    plt.plot(preds_tensor[:, U2_index],  label='Predicted U2', linestyle='--')
    plt.legend()
    plt.title(f"U_2_{dataset_name}")
    plt.xlabel('Sample')
    plt.ylabel('Value')

    plt.figure()
    plt.plot(targets[:, U3_index], label='True U3')
    plt.plot(preds_tensor[:, U3_index],  label='Predicted U3', linestyle='--')
    plt.legend()
    plt.title(f"U_3_{dataset_name}")
    plt.xlabel('Sample')
    plt.ylabel('Value')

    return average_loss

# %%
autoregressive_performance_plot(model=inverse_model, U_scaled=U_train_transformed, X_scaled=X_train_transformed, lag_input=lag_input, lag_state=lag_state,
                                ee_x_index=ee_x_index, ee_y_index=ee_y_index,
                                loss_fn=loss_fn, U1_index=U1_index, U2_index=U2_index, U3_index=U3_index, 
                                dataset_name="train_data") 

autoregressive_performance_plot(model=inverse_model, U_scaled=U_valid_transformed, X_scaled=X_valid_transformed, lag_input=lag_input, lag_state=lag_state,
                                ee_x_index=ee_x_index, ee_y_index=ee_y_index,
                                loss_fn=loss_fn, U1_index=U1_index, U2_index=U2_index, U3_index=U3_index, 
                                dataset_name="valid_data") 

autoregressive_performance_plot(model=inverse_model, U_scaled=U_test_transformed, X_scaled=X_test_transformed, lag_input=lag_input, lag_state=lag_state,
                                ee_x_index=ee_x_index, ee_y_index=ee_y_index,
                                loss_fn=loss_fn, U1_index=U1_index, U2_index=U2_index, U3_index=U3_index, 
                                dataset_name="test_data")
# Out:
# Average Loss of train_data: 0.013221096247434616
# Average Loss of valid_data: 0.005369611084461212
# Average Loss of test_data: 0.004960486199706793
# 0.004960486199706793

# %% [markdown]
# saving the model

# %%
model_data_directory = os.path.join(script_directory, "ik_model_lines_data")
os.makedirs(model_data_directory, exist_ok=True)
model_name = "IK_MLP_lines.pth" 
torch.save(inverse_model.state_dict(), os.path.join(model_data_directory, model_name))

# %% [markdown]
# saving the scalers

# %%
import pickle
data_scaler_filename = "data_scaler_lines.pkl"
input_scaler_filename = "input_scaler_lines.pkl" 
state_scaler_filename = "state_scaler_lines.pkl" 
ee_scaler_filename = "ee_xy_scaler.pkl"
with open(os.path.join(model_data_directory, data_scaler_filename), "wb") as file : 
    pickle.dump(data_scaler, file=file) 
with open(os.path.join(model_data_directory, input_scaler_filename), "wb") as file : 
    pickle.dump(input_scaler, file=file)
with open(os.path.join(model_data_directory, state_scaler_filename), "wb") as file : 
    pickle.dump(state_scaler, file=file)
with open(os.path.join(model_data_directory, ee_scaler_filename), "wb") as file : 
    pickle.dump(ee_scaler, file=file)
